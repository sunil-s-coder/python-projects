# %%
import pandas as pd

# %%
# Read data from Excel file 'people_basic.xlsx' located in the parent directory's data/raw folder
# and store it in a pandas DataFrame called 'df'
df = pd.read_excel(r"..\data\raw\people_basic.xlsx")

# %%
df
# Out:
#    emp_id   name  age  department  salary
# 0     101  Sunil   30          IT   75000
# 1     102  Anita   28          HR   62000
# 2     103  Rahul   35     Finance   88000
# 3     104   Neha   26          IT   68000
# 4     105  Kiran   40  Operations   92000

# %%
# Create a formatted string containing key DataFrame properties
df_properties = f"""Data type: {type(df)}  # Shows the Python class of the DataFrame
Dimension: {df.shape}  # Shows (rows, columns) as a tuple
Columns: {df.columns}  # Lists all column names
Rows/index range: {df.index}  # Shows the index range
Columns Data type: \n{df.dtypes}  # Shows data type of each column
"""

# Display the DataFrame properties
print(df_properties)
# Out:
# Data type: <class 'pandas.core.frame.DataFrame'>  # Shows the Python class of the DataFrame
# Dimension: (5, 5)  # Shows (rows, columns) as a tuple
# Columns: Index(['emp_id', 'name', 'age', 'department', 'salary'], dtype='object')  # Lists all column names
# Rows/index range: RangeIndex(start=0, stop=5, step=1)  # Shows the index range
# Columns Data type:
# emp_id         int64
# name          object
# age            int64
# department    object
# salary         int64
# dtype: object  # Shows data type of each column

# %%
#Series "age"
age = df["age"]
age
# Out:
# 0    30
# 1    28
# 2    35
# 3    26
# 4    40
# Name: age, dtype: int64

# %%
# Create a formatted string containing properties of the 'age' Series
series_properties = f"""Data type: {type(age)}  # Shows the Python type (pandas.Series)
Dimension: {age.shape}  # Shows the shape/length of the Series
columns: {age.index}  # Shows the index labels of the Series
Values: {age.values}  # Shows the underlying NumPy array of values
dtype: {age.dtype}  # Shows the data type of the elements in the Series
"""

# Print all the Series properties
print(series_properties)
# Out:
# Data type: <class 'pandas.core.series.Series'>  # Shows the Python type (pandas.Series)
# Dimension: (5,)  # Shows the shape/length of the Series
# columns: RangeIndex(start=0, stop=5, step=1)  # Shows the index labels of the Series
# Values: [30 28 35 26 40]  # Shows the underlying NumPy array of values
# dtype: int64  # Shows the data type of the elements in the Series
